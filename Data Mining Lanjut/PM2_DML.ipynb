# %%
nama = "khairul"

#ini komentar

if nama == "khairul":
  print(nama)
  print("selamat datang")

print("oke")
# Out:
# khairul
# selamat datang
# oke

# %%
namaDepan = "tatiek"
namaBelakang = "hurun"
NamaDepan = "khairul"

print(namaDepan)
print(namaBelakang)
# Out:
# tatiek
# hurun

# %%
# Mengambil Input
nama = input("Siapa nama kamu ")
umur = input("Berapa umur kamu ")

# Menampilkan output
print ("Hello",nama,"Umur kamu adalah",umur,"tahun")
print ("Hello "+nama+" Umur kamu adalah "+umur+" tahun")
print ("Hello {} Umur kamu adalah {} tahun".format(nama,umur))
print ("Hello %s Umur kamu adalah %s tahun" % (nama,umur))
# Out:
# Siapa nama kamu khairul
# Berapa umur kamu 20
# Hello khairul Umur kamu adalah 20 tahun
# Hello khairul Umur kamu adalah 20 tahun
# Hello khairul Umur kamu adalah 20 tahun
# Hello khairul Umur kamu adalah 20 tahun

# %%
input_angka = input("masukan angka ")
print(type(input_angka))
# Out:
# masukan angka 10
# <class 'str'>

# %%
bil1 = input("bilangan 1 : ")
bil2 = input("bilangan 2 : ")
hasil = int(bil1) + int(bil2)
print("hasil dari {} + {} adalah {}".format(bil1, bil2, hasil))
# Out:
# bilangan 1 : 20
# bilangan 2 : 20
# hasil dari 20 + 20 adalah 40

# %% [markdown]
# **LATIHAN**

# %%
bil1 = int(input('Masukan Bilangan ke-1 = '))
bil2 = int(input('Masukan Bilangan ke-2 = '))

print("")
print("Dan Hasilnya Adalah..")
print("")

tambah = bil1+bil2
kali = bil1*bil2
print("Hasil tambahnya adalah = ", tambah)
print("Hasilnya perkaliannya adalah = ", kali)
# Out:
# Masukan Bilangan ke-1 = 5
# Masukan Bilangan ke-2 = 5
#
# Dan Hasilnya Adalah..
#
# Hasil tambahnya adalah =  10
# Hasilnya perkaliannya adalah =  25

# %%
r = int(input('jari jari = '))
t = int(input('tinggi = '))
phi = 3.14
volume = 1/3*phi*r*2**t
print('volume', volume)
# Out:
# jari jari = 5
# tinggi = 10
# volume 5358.933333333333

# %%
nama = input("Masukan Nama Anda = ")
jabatan = input("Masukan Jabatan Anda = ")
gaji = int(input("Masukan Gaji Anda = "))
pajak = 10/100*gaji
total = gaji-pajak
print("Pegawai dengan nama", nama, "dan jabatan", jabatan, "\ndengan gaji", gaji, "harus membayar pajak sebesar", pajak, "\nTotal yang didapat bersih", total)
# Out:
# Masukan Nama Anda = khairul
# Masukan Jabatan Anda = manager
# Masukan Gaji Anda = 10000000
# Pegawai dengan nama khairul dan jabatan manager
# dengan gaji 10000000 harus membayar pajak sebesar 1000000.0
# Total yang didapat bersih 9000000.0
