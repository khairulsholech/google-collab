# %% [markdown]
# **Membuat Variabel di Python**

# %%
variabel_ku = "ini isi variabel"
variabel2 = 20

print(variabel_ku)
print(variabel2)
# Out:
# ini isi variabel
# 20

# %% [markdown]
# Menghapus Variabel

# %%
nama = "Khairul Sholech"
name = "P"
print(nama)

del(nama)
print (name)
# Out:
# Khairul Sholech
# P

# %% [markdown]
# Tipe Data dan Jenis-jenis Tipe data

# %%
nama_ku = "Khairul Sholech"
umur = 20
tinggi = 188.22

type(nama_ku)
# Out:
# str

# %%
type(umur)
# Out:
# int

# %%
type(tinggi)
# Out:
# float

# %%
usia = True
type(usia)
# Out:
# bool

# %% [markdown]
# 1. Tipe Data Angka

# %%
harga = 12000 #tipe int
berat = 23.12 #float
jarak = 3e3 #float 3000.0, huruf e artinya eksponen 10

print(harga,berat, jarak)
# Out:
# 12000 23.12 3000.0

# %% [markdown]
# 2. Tipe Data Teks

# %%
nama = "ivan"
jenis_kelamin = 'L'
alamat = """
  Jl. Suka Karya, No 32. RT Kode,
  Kelurahan Mawar, Jakarta
"""

agama = 'islam'
print(nama, jenis_kelamin, alamat, agama)
# Out:
# ivan L
#   Jl. Suka Karya, No 32. RT Kode,
#   Kelurahan Mawar, Jakarta
#  islam

# %% [markdown]
# 3. Tipe data boolean

# %%
bergerak = True
nyala = 1 #sebenarnya tipenya int, tapi bisa juga menjadi bool

# %% [markdown]
# Contoh Program dengan Menggunakan Variabel dan Tipe Data

# %%
# Program bio data penduduk desa X
# Membuat variabel beserta isinya (nilainya)
nama = "Khairul"
alamat = 'pluit'
umur = 19
tinggi = 170.5
menikah = False

# Mencetak isi variabel
print("Nama : ", nama)
print("Alamat : ", alamat)
print("Umur : ", umur)
print("Tinggi : ", tinggi)
if(menikah):
  print("Status : Menikah")
else:
  print ("Status : Belum Menikah")
# Out:
# Nama :  Khairul
# Alamat :  pluit
# Umur :  19
# Tinggi :  170.5
# Status : Belum Menikah

# %% [markdown]
# Konversi Tipe Data

# %%
a = 10
b = 3
c = a/b
print(c)
# Out:
# 3.3333333333333335

# %%
a = 10
b = 3
c = float(a)/float(b)
print(c)
# Out:
# 3.3333333333333335

# %% [markdown]
# **OPERATOR PYTHON**

# %% [markdown]
# 1. Operator Aritmatika

# %%
# file: operator_aritmatika.py

# Ambil input untuk mengisi nilai
a = int(input("Inputkan nilai a: "))
b = int(input("Inputkan nilai b: "))

# Menggunakan operator penjumlahan
c = a + b
print("Hasil %d + %d = %d" % (a,b,c))

# Operator Pengurangan
c = a -b
print("Hasil %d - %d = %d" % (a,b,c))

# Operator Perkalian
c = a * b
print ("Hasil %d * %d = %d" % (a,b,c))

# Operator Pembagian
c = a / b
print ("Hasil %d / %d = %d" % (a,b,c))

# Operator Sisa Bagi
c = a % b
print ("Hasil %d %% %d = %d" % (a,b,c))

# OperatorPangkat
c = a ** b
print ("Hasil %d ** %d = %d" % (a,b,c))
# Out:
# Inputkan nilai a: 5
# Inputkan nilai b: 5
# Hasil 5 + 5 = 10
# Hasil 5 - 5 = 0
# Hasil 5 * 5 = 25
# Hasil 5 / 5 = 1
# Hasil 5 % 5 = 0
# Hasil 5 ** 5 = 3125

# %% [markdown]
# 2. Operator Penugasan

# %%
# file: operator_penugasan.py
# Ambil input untuk mengisi nilai
a = int(input("Inputkan nilai a: "))
# ^
# | contoh operator penugasan untuk mengisi nilai
print ("Nilai a = %d" % a)
# Coba kita jumlahkan nilai a dengan opertor penugasan
a += 5
# ^
# |
# contoh operator penugasan untuk menjumlahkan
# Setelah nilai a ditambah 5, coba kita lihat isinya
print ("Nilai setelah ditambah 5:")
print ("a = %d" % a)
# Out:
# Inputkan nilai a: 5
# Nilai a = 5
# Nilai setelah ditambah 5:
# a = 10

# %%
# Ambil input untuk mengisi nilai
a = int(input("Inputkan nilai a: "))
# tambahkan dengan 2
a += 2
# kurangi 3
a -= 3
# kali 10
a *= 10
# bagi dengan 4
a /= 4
# pangkat 10
a **= 10
# Berapakah nilai a sekarang?
print ("Nilai a adalah %d" % a)
# Out:
# Inputkan nilai a: 5
# Nilai a adalah 10000000000

# %% [markdown]
# 3. Operator Perbandingan

# %%
# file: operator_pembanding.py
a = int(input("Inputkan nilai a: "))
b = int(input("Inputkan nilai b: "))

# apakah a sama dengan b?
c = a == b
print ("Apakah %d == %d: %r" % (a,b,c))

# apakah a < b?
c = a < b
print ("Apakah %d < %d: %r" % (a,b,c))

# apakah a > b?
c = a > b
print ("Apakah %d > %d: %r" % (a,b,c))

# apakah a <= b?
c = a <= b
print ("Apakah %d <= %d: %r" % (a,b,c))

# apakah a >= b?
c = a >= b
print ("Apakah %d >= %d: %r" % (a,b,c))

# apakah a != b?
c = a != b
print ("Apakah %d != %d: %r" % (a,b,c))
# Out:
# Inputkan nilai a: 5
# Inputkan nilai b: 2
# Apakah 5 == 2: False
# Apakah 5 < 2: False
# Apakah 5 > 2: True
# Apakah 5 <= 2: False
# Apakah 5 >= 2: True
# Apakah 5 != 2: True

# %% [markdown]
# 4. Operator Logika

# %%
a = True
b = False
# Logika AND
c = a and b
print ("%r and %r = %r" % (a,b,c))
# Logika OR
c = a or b
print ("%r or %r = %r" % (a,b,c))
# Logika Not
c = not a
print ("not %r = %r" % (a,c))
# Out:
# True and False = False
# True or False = True
# not True = False

# %% [markdown]
# 5. Operator Bitwise

# %%
a = int(input("Masukan nilai a: "))
b = int(input("Masukan nilai b: "))
# Operasi AND
c = a & b
print ("a & b = %s" % c)
# Operasi OR
c = a | b
print ("a | b = %s" % c)
# Operasi XOR
c = a ^ b
print ("a ^ b = %s" % c)
# Operasi Not
c = ~a
print ("~a = %s" % c)
# Operasi shift left (tukar posisi biner)
c = a << b
print ("a << b = %s" % c)
# Operasi shift right (tukar posisi biner)
c = a >> b
print ("a >> b = %s" % c)
# Out:
# Masukan nilai a: 2
# Masukan nilai b: 2
# a & b = 2
# a | b = 2
# a ^ b = 0
# a = -3
# a << b = 8
# a >> b = 0

# %% [markdown]
# 6. Operator Ternary

# %%
aku = (umur < 10) ? "bocah" : "dewasa"
# Out:
#   File "<ipython-input-67-36f42cb6a59e>", line 1
#     aku = (umur < 10) ? "bocah" : "dewasa"
#                       ^
# SyntaxError: invalid syntax

# %%
umur = int(input("berapa umur kamu? "))
aku = "bocah" if umur < 10 else "dewasa"
print(aku)
# Out:
# berapa umur kamu? 19
# dewasa

# %% [markdown]
# **TUGAS**
#
# Kelompok 3
# 1. Aliffio Syah Maulana 41519120065
# 2. Reza Arrofi 41519120044
# 3. Khairul Sholech 41519120068

# %% [markdown]
# 1. Buatlah program dengan menampilkan Nilai rata-rata dari variabel berikut :Nilai  1  = 45,  Nilai  2  = 23, Nilai  3  = 71 danNilai 4  = 81.  Tentukan nilai  rata-rata dari keempatvariabel?

# %%
Nilai_1 = 45
Nilai_2 = 23
Nilai_3 = 71
Nilai_4 = 81

Hasil = int((Nilai_1 + Nilai_2 + Nilai_3 + Nilai_4)/4)

print("Nilai rata-rata dari keempat variabel tersebut adalah",Hasil)
print ("Nilai rata-rata dari %d, %d, %d, %d adalah %d" % (Nilai_1,Nilai_2,Nilai_3,Nilai_4,Hasil))
# Out:
# Nilai rata-rata dari keempat variabel tersebut adalah 55
# Nilai rata-rata dari 45, 23, 71, 81 adalah 55

# %%
Nilai_1 = int(input("Masukan nilai 1: "))
Nilai_2 = int(input("Masukan nilai 2: "))
Nilai_3 = int(input("Masukan nilai 3: "))
Nilai_4 = int(input("Masukan nilai 4: "))

Hasil = int((Nilai_1 + Nilai_2 + Nilai_3 + Nilai_4)/4)

print("Nilai rata-rata dari keempat variabel tersebut adalah",Hasil)
print ("Nilai rata-rata dari %d, %d, %d, %d adalah %d" % (Nilai_1,Nilai_2,Nilai_3,Nilai_4,Hasil))
# Out:
# Masukan nilai 1: 10
# Masukan nilai 2: 9
# Masukan nilai 3: 7
# Masukan nilai 4: 2
# Nilai rata-rata dari keempat variabel tersebut adalah 7

# %% [markdown]
# 2. Buatlah program dengan ketentuan sebagai berikut:Menentukan Harga setelah didiskon 10% dari harga barang senilai Rp.1.000.000

# %%
Harga_barang = 1000000
Diskon = 0.1*Harga_barang
Harga_setelah_diskon = Harga_barang-Diskon

print(Harga_setelah_diskon)
# Out:
# 900000.0
